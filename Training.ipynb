# %%
import torch 
from noise2noise.datasets import load_dataset
from noise2noise.noise2noise import Noise2Noise

# %%
class Args:
    train_source_dir = 'noise2noise/data/train/source'
    train_target_dir = 'noise2noise/data/train/target'
    valid_source_dir = 'noise2noise/data/valid/source'
    valid_target_dir = 'noise2noise/data/valid/target'
    ckpt_save_path = 'ckpts'
    ckpt_overwrite = True
    report_interval = 7
    train_size = None
    valid_size = None
    learning_rate = 0.001
    adam = [0.9, 0.99, 1e-08]
    batch_size = 7
    nb_epochs = 30
    loss = 'l2'
    cuda = torch.cuda.is_available()
    plot_stats = True
    noise_type = 'gaussian'
    noise_param = 50
    seed = None
    crop_size = 128
    clean_targets = False
    no_crop = True
    add_noise = False

params = Args()

# %%
train_loader = load_dataset(
    source_dir=params.train_source_dir,
    target_dir=params.train_target_dir,
    redux=params.train_size,
    params=params,
    shuffled=True,
    add_noise=params.add_noise
)

valid_loader = load_dataset(
    source_dir=params.valid_source_dir,
    target_dir=params.valid_target_dir,
    redux=params.valid_size,
    params=params,
    shuffled=False,
    add_noise=params.add_noise
)

# %%
n2n = Noise2Noise(params, trainable=True)
# Out:
# Noise2Noise: Learning Image Restoration without Clean Data (Lethinen et al., 2018)
# /zhome/ahmadfn/.pyenv/versions/3.8.10/envs/n2n_joey/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
n2n.train(train_loader, valid_loader)
# Out:
# Training parameters:
#   Cuda = True
#
# EPOCH 1 / 30
# Batch 7 / 7 | Avg loss: 0.37647 | Avg train time / batch: 106 ms
# Train time: 0:00:01 | Valid time: 0:00:00 | Valid loss: 0.07140 | Avg PSNR: 59.75 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 2 / 30
# Batch 7 / 7 | Avg loss: 0.03890 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01927 | Avg PSNR: 65.45 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 3 / 30
# Batch 7 / 7 | Avg loss: 0.02073 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01849 | Avg PSNR: 65.60 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 4 / 30
# Batch 7 / 7 | Avg loss: 0.01743 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01694 | Avg PSNR: 66.03 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 5 / 30
# Batch 7 / 7 | Avg loss: 0.01621 | Avg train time / batch: 10 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01633 | Avg PSNR: 66.31 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 6 / 30
# Batch 7 / 7 | Avg loss: 0.01548 | Avg train time / batch: 10 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01501 | Avg PSNR: 66.70 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 7 / 30
# Batch 7 / 7 | Avg loss: 0.01479 | Avg train time / batch: 16 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01412 | Avg PSNR: 67.04 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 8 / 30
# Batch 7 / 7 | Avg loss: 0.01436 | Avg train time / batch: 13 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01377 | Avg PSNR: 67.17 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 9 / 30
# Batch 7 / 7 | Avg loss: 0.01363 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01332 | Avg PSNR: 67.30 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 10 / 30
# Batch 7 / 7 | Avg loss: 0.01326 | Avg train time / batch: 13 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01341 | Avg PSNR: 67.18 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 11 / 30
# Batch 7 / 7 | Avg loss: 0.01277 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01221 | Avg PSNR: 67.79 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 12 / 30
# Batch 7 / 7 | Avg loss: 0.01246 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01173 | Avg PSNR: 67.98 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 13 / 30
# Batch 7 / 7 | Avg loss: 0.01239 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01177 | Avg PSNR: 68.07 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 14 / 30
# Batch 7 / 7 | Avg loss: 0.01164 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01132 | Avg PSNR: 68.25 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 15 / 30
# Batch 7 / 7 | Avg loss: 0.01155 | Avg train time / batch: 10 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01414 | Avg PSNR: 67.11 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 16 / 30
# Batch 7 / 7 | Avg loss: 0.01210 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01154 | Avg PSNR: 68.20 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 17 / 30
# Batch 7 / 7 | Avg loss: 0.01179 | Avg train time / batch: 10 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01094 | Avg PSNR: 68.52 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 18 / 30
# Batch 7 / 7 | Avg loss: 0.01120 | Avg train time / batch: 16 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01064 | Avg PSNR: 68.68 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 19 / 30
# Batch 7 / 7 | Avg loss: 0.01085 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01174 | Avg PSNR: 67.91 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 20 / 30
# Batch 7 / 7 | Avg loss: 0.01143 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01126 | Avg PSNR: 68.17 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 21 / 30
# Batch 7 / 7 | Avg loss: 0.01100 | Avg train time / batch: 13 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01045 | Avg PSNR: 68.69 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 22 / 30
# Batch 7 / 7 | Avg loss: 0.01059 | Avg train time / batch: 10 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01124 | Avg PSNR: 68.22 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 23 / 30
# Batch 7 / 7 | Avg loss: 0.01055 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01027 | Avg PSNR: 68.82 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 24 / 30
# Batch 7 / 7 | Avg loss: 0.01047 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01029 | Avg PSNR: 68.76 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 25 / 30
# Batch 7 / 7 | Avg loss: 0.01049 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01012 | Avg PSNR: 68.94 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 26 / 30
# Batch 7 / 7 | Avg loss: 0.01018 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01028 | Avg PSNR: 68.92 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 27 / 30
# Batch 7 / 7 | Avg loss: 0.01027 | Avg train time / batch: 15 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01019 | Avg PSNR: 68.94 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 28 / 30
# Batch 7 / 7 | Avg loss: 0.01008 | Avg train time / batch: 14 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01020 | Avg PSNR: 68.84 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 29 / 30
# Batch 7 / 7 | Avg loss: 0.01011 | Avg train time / batch: 13 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.00997 | Avg PSNR: 69.07 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# EPOCH 30 / 30
# Batch 7 / 7 | Avg loss: 0.01014 | Avg train time / batch: 12 ms
# Train time: 0:00:00 | Valid time: 0:00:00 | Valid loss: 0.01058 | Avg PSNR: 68.65 dB
# Saving checkpoint to: ckpts/gaussian/n2n-gaussian.pt
#
# Training done! Total elapsed time: 0:00:53
